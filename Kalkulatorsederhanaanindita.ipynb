# %% [markdown]
# <a href="https://colab.research.google.com/github/aninditapranesti2025-lgtm/KKA-X-Semester-1-AninditaIntanPuriPranesti/blob/main/Kalkulatorsederhanaanindita.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Diameter = int(input("Masukan diameter dari bola (cm):"))
Jari_jari = int(input("Masukan jari-jari dari bola (cm):"))

volume = (4/3) * (22/7) * Jari_jari**3

print(f"\nvolume dari bola yaitu {round(volume)} cm^3")
# Out:
# Masukan diameter dari bola (cm):14
# Masukan jari-jari dari bola (cm):7
#
# volume dari bola yaitu 1437 cm^3
